# %%
from selenium import webdriver
from pandas import DataFrame
from selenium.webdriver.common.keys import Keys
import time
import getpass
import urllib.request
import requests
import numpy as np
import pymysql

import bs4
import time

# %%
from bs4 import BeautifulSoup
from urllib.request import urlopen
import re
import pandas as pd
import csv
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

# %%
req = requests.get('https://finance.naver.com/marketindex/exchangeDetail.nhn?marketindexCd=FX_CNYKRW')
html = req.text
soup = BeautifulSoup(html, 'html.parser')
my_titles = soup.select(
    '#container > div.h_company > h2'
    )
my_curr = soup.select(
    '#container > div.h_company > div.description > span'
    )

# my_titles는 list 객체
for title in my_titles:
    country=title.text
    print(country)
   
for curr in my_curr:
    curr=curr.text
    print(curr)
# Out:
#  중국
# CNYKRW

# %%
chromedriver_dir = r'/Users/jungjiu/my-project/chromedriver'
driver = webdriver.Chrome(chromedriver_dir)

# %%
base_url = 'https://finance.naver.com/marketindex/exchangeDailyQuote.nhn?marketindexCd=FX_%s&page={}'%(curr)
cur_list=[] 
date_list=[]
for n in range (0,390) :
    print("page",n+1)
    url = base_url.format(n+1)
    driver.get(url)
    time.sleep(1)
    date=driver.find_elements_by_tag_name('body > div > table > tbody >tr > td.date')
    currency=driver.find_elements_by_tag_name('body > div > table > tbody >tr > td:nth-child(2)')
    
    for dates in date: 
        dates=dates.text
#         print(dates)
        date_list+=[dates]
    for currencys in currency:        
        
        cur=currencys.text
#         print(cur)
        cur_list+=[cur]
print(date_list)
# print(cur_list)
        
    
#     my_dict = pd.DataFrame(cur_list)
#     display(pd.DataFrame(my_dict))
# Out:
# page 1
# page 2
# page 3
# page 4
# page 5
# page 6
# page 7
# page 8
# page 9
# page 10
# page 11
# page 12
# page 13
# page 14
# page 15
# page 16
# page 17
# page 18
# page 19
# page 20
# page 21
# page 22
# page 23
# page 24
# page 25
# page 26
# page 27
# page 28
# page 29
# page 30
# page 31
# page 32
# page 33
# page 34
# page 35
# page 36
# page 37
# page 38
# page 39
# page 40
# page 41
# page 42
# page 43
# page 44
# page 45
# page 46
# page 47
# page 48
# page 49
# page 50
# page 51
# page 52
# page 53
# page 54
# page 55
# page 56
# page 57
# page 58
# page 59
# page 60
# page 61
# page 62
# page 63
# page 64
# page 65
# page 66
# page 67
# page 68
# page 69
# page 70
# page 71
# page 72
# page 73
# page 74
# page 75
# page 76
# page 77
# page 78
# page 79
# page 80
# page 81
# page 82
# page 83
# page 84
# page 85
# page 86
# page 87
# page 88
# page 89
# page 90
# page 91
# page 92
# page 93
# page 94
# page 95
# page 96
# page 97
# page 98
# page 99
# page 100
# ...

# %%
df=pd.DataFrame([date_list,cur_list],index= ['Date', curr]).T

# %%
from datetime import datetime

df['%s' % (curr)]=df['%s' % (curr)].replace('\,','',regex=True).astype(float) 
df['Date']=pd.to_datetime(df['Date'],format='%Y.%m.%d').dt.strftime("%Y-%m-%d");


df.to_csv("%s.csv" % (curr))

print(df)
# Out:
#             Date  CNYKRW
# 0     2019-12-05  168.80
# 1     2019-12-04  169.07
# 2     2019-12-03  168.40
# 3     2019-12-02  168.34
# 4     2019-11-29  167.98
# ...          ...     ...
# 3886  2004-04-19  139.38
# 3887  2004-04-16  140.16
# 3888  2004-04-14  139.10
# 3889  2004-04-13  137.86
# 3890  2004-04-12  137.95
#
# [3891 rows x 2 columns]
